# %% [markdown]
# # Data Mining

# %%
from matplotlib import rcParams
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go
import plotly.express as px
import re
from datetime import date
import datetime
from ast import literal_eval
#from pandas.plotting import register_matplotlib_converters
import glob
#register_matplotlib_converters()

today = date.today()
sns.set(style="white", palette="pastel",font_scale=1.5, rc={"lines.linewidth": 2.5,'figure.figsize':(11.7,8.27)})

# %%
pd.options.display.max_columns = None

# %%
import glob

path = r'C:\Users\neomo\Documents\GitHub\data_science_project_2\data' # use your path
all_files = glob.glob(path + "/*.csv")

li = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    li.append(df)

df = pd.concat(li, axis=0, ignore_index=True)

# %% [markdown]
# # Data Cleaning

# %%
df[np.invert(df.permissions.isnull())].permissions.head()
# Out:
# 201     []
# 368     []
# 382     []
# 1343    []
# 1389    []
# Name: permissions, dtype: object

# %%
df[np.invert(df.is_starred.isnull())].is_starred.head()
# Out:
# 201     False
# 368     False
# 382     False
# 1343    False
# 1389    False
# Name: is_starred, dtype: object

# %%
df[np.invert(df.is_backing.isnull())].is_backing.head()
# Out:
# 201     False
# 368     False
# 382     False
# 1343    False
# 1389    False
# Name: is_backing, dtype: object

# %%
df[np.invert(df.friends.isnull())].friends.head()
# Out:
# 201     []
# 368     []
# 382     []
# 1343    []
# 1389    []
# Name: friends, dtype: object

# %%
col_date=['state_changed_at','created_at','launched_at','deadline']
for i in col_date:
    df[i]=df[i].apply(lambda x:
    datetime.datetime.fromtimestamp(int(x)).strftime("%Y-%m-%d %H:%M:%S"))

# %%
df.state_changed_at = pd.to_datetime(df.state_changed_at)
df.created_at = pd.to_datetime(df.created_at)
df.launched_at = pd.to_datetime(df.launched_at)
df.deadline = pd.to_datetime(df.deadline)

# %%
df.shape
# Out:
# (209222, 37)

# %%
df.drop(["permissions","is_backing","is_starred","friends"], axis=1, inplace=True)

# %%
df.dropna(inplace=True)

# %%
df = df.sort_values(["id","state_changed_at"])

# %%
df.drop_duplicates(subset="id", inplace=True, keep="last")

# %%
df.drop(["id"], inplace=True, axis=1)

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# ## location

# %%
lat={"US":39.9,"GB":53.44,"FR":47.07,"AU":-25,"NZ":-41.93,'ES':40.06, 'IT':43.03, 'NO':61.52, 'NL':52.2, 'CA':60.26, 'SG':1.37,
       'MX':24.25, 'SE':62.89, 'IE':53.36, 'DE':51.08, 'BE':50.68, 'HK':22.39, 'AT':47.69, 'JP':36.59, 'DK':55.95, 'CH':46.89, 'LU':49.64}
long={"US": -102.1,"GB":-1.64,"FR":2.4,"AU":134.12,"NZ":172.88,'ES':-3.5, 'IT':12.6, 'NO':9.49, 'NL':5.65, 'CA':-110.66, 'SG':103.81,
       'MX':-102.45, 'SE':16.88, 'IE':-7.62, 'DE':10.34, 'BE':4.77, 'HK':114.16, 'AT':14.85, 'JP':139.16, 'DK':9.4, 'CH':8.21, 'LU':6.14}

# %%
df["lat"]=[lat[elm] for elm in df.country.values]
df["long"]=[long[elm] for elm in df.country.values]

# %% [markdown]
# ## average pledge

# %%
df["average_pledge"] = round((df.converted_pledged_amount / df.backers_count),2)

# %%
df["average_pledge"].fillna(0, inplace=True)

# %% [markdown]
# ## convert goal to USD

# %%
df['usd_goal'] = round((df.goal * df.static_usd_rate), 2)

# %% [markdown]
# ## categories

# %%
cat = [eval(i)["slug"] for i in df.category]

# %%
cat2 = [elm.split("/") for elm in cat]

# %%
main_cat = [elm[0] for elm in cat2]
sub_cat = [elm[1] if len(elm) > 1 else elm[0] for elm in cat2]

# %%
df["cat"] = cat
df["main_cat"] = main_cat
df["sub_cat"] = sub_cat

# %% [markdown]
# ## profile ids

# %%
ids = [int(re.findall(r'\d+', i)[0]) for i in df.creator]

# %%
id_counts = [ids.count(elm) for elm in ids]

# %%
df["profile_id_counts"] = id_counts

# %% [markdown]
# ## slug length

# %%
key_word_count = [len(elm.split("-")) for elm in df.slug]

# %%
df["key_word_count"] = key_word_count

# %% [markdown]
# ## start month

# %%
df['month'] = pd.DatetimeIndex(df['launched_at']).month
df["month"] = df.month.astype("object")

# %% [markdown]
# ## launch year

# %%
df['year'] = pd.DatetimeIndex(df['launched_at']).year
df["year"] = df.year.astype("object")

# %% [markdown]
# ## launch day

# %%
df['weekday_start'] = pd.DatetimeIndex(df['launched_at']).weekday+1
df["weekday_start"] = df.weekday_start.astype("object")

# %% [markdown]
# ## end day

# %%
df['weekday_end'] = pd.DatetimeIndex(df['deadline']).weekday+1
df["weekday_end"] = df.weekday_end.astype("object")

# %% [markdown]
# ## duration

# %%
df['duration'] = df.deadline - df.launched_at
df['duration'] = df['duration'].dt.floor('d')
df['duration'] = df['duration'].dt.days.astype('int16')

# %% [markdown]
# ## blurb length

# %%
df['blurb_len'] = [elm.split(" ") for elm in df.blurb]
df['blurb_len'] = [len(i) for i in df['blurb_len']]

# %% [markdown]
# # date exploration

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 181996 entries, 20003 to 51373
# Data columns (total 47 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   backers_count             181996 non-null  int64
#  1   blurb                     181996 non-null  object
#  2   category                  181996 non-null  object
#  3   converted_pledged_amount  181996 non-null  int64
#  4   country                   181996 non-null  object
#  5   created_at                181996 non-null  datetime64[ns]
#  6   creator                   181996 non-null  object
#  7   currency                  181996 non-null  object
#  8   currency_symbol           181996 non-null  object
#  9   currency_trailing_code    181996 non-null  bool
#  10  current_currency          181996 non-null  object
#  11  deadline                  181996 non-null  datetime64[ns]
#  12  disable_communication     181996 non-null  bool
#  13  fx_rate                   181996 non-null  float64
#  14  goal                      181996 non-null  float64
#  15  is_starrable              181996 non-null  bool
#  16  launched_at               181996 non-null  datetime64[ns]
#  17  location                  181996 non-null  object
#  18  name                      181996 non-null  object
#  19  photo                     181996 non-null  object
#  20  pledged                   181996 non-null  float64
#  21  profile                   181996 non-null  object
#  22  slug                      181996 non-null  object
#  23  source_url                181996 non-null  object
#  24  spotlight                 181996 non-null  bool
#  25  staff_pick                181996 non-null  bool
#  26  state                     181996 non-null  object
#  27  state_changed_at          181996 non-null  datetime64[ns]
#  28  static_usd_rate           181996 non-null  float64
#  29  urls                      181996 non-null  object
#  30  usd_pledged               181996 non-null  float64
#  31  usd_type                  181996 non-null  object
#  32  lat                       181996 non-null  float64
#  33  long                      181996 non-null  float64
#  34  average_pledge            181996 non-null  float64
#  35  usd_goal                  181996 non-null  float64
#  36  cat                       181996 non-null  object
#  37  main_cat                  181996 non-null  object
#  38  sub_cat                   181996 non-null  object
#  39  profile_id_counts         181996 non-null  int64
#  40  key_word_count            181996 non-null  int64
#  41  month                     181996 non-null  object
#  42  year                      181996 non-null  object
#  43  weekday_start             181996 non-null  object
#  44  weekday_end               181996 non-null  object
#  45  duration                  181996 non-null  int16
#  46  blurb_len                 181996 non-null  int64
# dtypes: bool(5), datetime64[ns](4), float64(9), int16(1), int64(5), object(23)
# memory usage: 59.5+ MB

# %% [markdown]
# ## splitting dataframes

# %%
dfsuc = df[df.state == "successful"]

# %%
dfsuc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 94614 entries, 20003 to 51373
# Data columns (total 47 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   backers_count             94614 non-null  int64
#  1   blurb                     94614 non-null  object
#  2   category                  94614 non-null  object
#  3   converted_pledged_amount  94614 non-null  int64
#  4   country                   94614 non-null  object
#  5   created_at                94614 non-null  datetime64[ns]
#  6   creator                   94614 non-null  object
#  7   currency                  94614 non-null  object
#  8   currency_symbol           94614 non-null  object
#  9   currency_trailing_code    94614 non-null  bool
#  10  current_currency          94614 non-null  object
#  11  deadline                  94614 non-null  datetime64[ns]
#  12  disable_communication     94614 non-null  bool
#  13  fx_rate                   94614 non-null  float64
#  14  goal                      94614 non-null  float64
#  15  is_starrable              94614 non-null  bool
#  16  launched_at               94614 non-null  datetime64[ns]
#  17  location                  94614 non-null  object
#  18  name                      94614 non-null  object
#  19  photo                     94614 non-null  object
#  20  pledged                   94614 non-null  float64
#  21  profile                   94614 non-null  object
#  22  slug                      94614 non-null  object
#  23  source_url                94614 non-null  object
#  24  spotlight                 94614 non-null  bool
#  25  staff_pick                94614 non-null  bool
#  26  state                     94614 non-null  object
#  27  state_changed_at          94614 non-null  datetime64[ns]
#  28  static_usd_rate           94614 non-null  float64
#  29  urls                      94614 non-null  object
#  30  usd_pledged               94614 non-null  float64
#  31  usd_type                  94614 non-null  object
#  32  lat                       94614 non-null  float64
#  33  long                      94614 non-null  float64
#  34  average_pledge            94614 non-null  float64
#  35  usd_goal                  94614 non-null  float64
#  36  cat                       94614 non-null  object
#  37  main_cat                  94614 non-null  object
#  38  sub_cat                   94614 non-null  object
#  39  profile_id_counts         94614 non-null  int64
#  40  key_word_count            94614 non-null  int64
#  41  month                     94614 non-null  object
#  42  year                      94614 non-null  object
#  43  weekday_start             94614 non-null  object
#  44  weekday_end               94614 non-null  object
#  45  duration                  94614 non-null  int16
#  46  blurb_len                 94614 non-null  int64
# dtypes: bool(5), datetime64[ns](4), float64(9), int16(1), int64(5), object(23)
# memory usage: 30.9+ MB

# %%
dffail = df[df.state == "failed"]

# %%
dffail.head()
# Out:
#         backers_count                                              blurb  \
# 148516              4  Raising money to help my grandmother recover f...
# 44169              18  A sanctuary for humans and felines alike! Come...
# 80052              42  Taste Makers is a socially conscious brand tha...
# 93623               3  All your herbal tea remedies here. From colds ...
# 199356              1  An easy to use call quality monitoring and sal...
#
#                                                  category  \
# 148516  {"id":44,"name":"World Music","slug":"music/wo...
# 44169   {"id":314,"name":"Spaces","slug":"food/spaces"...
# 80052   {"id":269,"name":"Ready-to-wear","slug":"fashi...
# 93623   {"id":307,"name":"Drinks","slug":"food/drinks"...
# 199356  {"id":51,"name":"Software","slug":"technology/...
#
#         converted_pledged_amount country          created_at  \
# 148516                        62      US 2016-10-19 14:13:18
# 44169                        776      US 2015-10-25 16:32:25
# 80052                       2158      CA 2015-03-15 05:40:34
# 93623                         96      US 2018-08-22 04:02:08
# 199356                        67      GB 2017-06-23 12:04:59
#
#                                                   creator currency  \
# 148516  {"id":1501687606,"name":"Devan Porter","is_reg...      USD
# 44169   {"id":920978851,"name":"Tori","is_registered":...      USD
# 80052   {"id":1827655104,"name":"Taste Makers By Trish...      CAD
# 93623   {"id":160842473,"name":"Vito Finazzo","is_regi...      USD
# 199356  {"id":1108956785,"name":"Robbie Rouse","is_reg...      GBP
#
#        currency_symbol  currency_trailing_code current_currency  \
# 148516               $                    True              USD
# 44169                $                    True              USD
# 80052                $                    True              USD
# 93623                $                    True              USD
# 199356               £                   False              USD
#
#                   deadline  disable_communication   fx_rate     goal  \
# 148516 2016-11-18 15:32:40                  False  1.000000  15000.0
# 44169  2015-11-26 17:25:33                  False  1.000000  20000.0
# 80052  2015-07-30 20:28:11                  False  0.751224  18000.0
# 93623  2018-10-21 05:51:56                  False  1.000000   2500.0
# 199356 2017-09-21 13:46:44                  False  1.308394   1500.0
#
#         is_starrable         launched_at  \
# 148516         False 2016-10-19 15:32:40
# 44169          False 2015-10-27 16:25:33
# 80052          False 2015-06-15 20:28:11
# 93623          False 2018-08-22 05:51:56
# 199356         False 2017-08-22 13:46:44
#
#                                                  location  \
# 148516  {"id":2381475,"name":"Cleveland","slug":"cleve...
# 44169   {"id":12784759,"name":"61704","slug":null,"sho...
# 80052   {"id":9807,"name":"Vancouver","slug":"vancouve...
# 93623   {"id":2440603,"name":"Livonia","slug":"livonia...
# 199356  {"id":24083,"name":"Huddersfield","slug":"hudd...
#
#                                                      name  \
# 148516                                 Grandma's are Life
# 44169   Puss N' Books: A relaxing cat cafe and bookstore.
# 80052                             TASTE MAKERS BY TRISH P
# 93623                                         Herbal Teas
# 199356  Call quality and sales performance management ...
#
#                                                     photo  pledged  \
# 148516  {"key":"assets/014/175/220/334630c3d0b5814d022...     62.0
# 44169   {"key":"assets/012/288/845/06e1a48097ecbb3d5cb...    776.0
# 80052   {"key":"assets/012/069/475/8acca15eaf286348e89...   2798.0
# 93623   {"key":"assets/022/305/215/4c29d9244dbc1614f85...     96.0
# 199356  {"key":"assets/017/225/437/7bb9786c79f0ae57cd6...     50.0
#
#                                                   profile  \
# 148516  {"id":2725234,"project_id":2725234,"state":"in...
# 44169   {"id":2192472,"project_id":2192472,"state":"in...
# 80052   {"id":1770331,"project_id":1770331,"state":"in...
# 93623   {"id":3453654,"project_id":3453654,"state":"in...
# 199356  {"id":3049453,"project_id":3049453,"state":"in...
#
#                                                      slug  \
# 148516                                  grandmas-are-life
# 44169      puss-n-books-a-relaxing-cat-cafe-and-bookstore
# 80052                             taste-makers-by-trish-p
# 93623                                         herbal-teas
# 199356  employee-evaluation-and-performance-management...
#
#                                                source_url  spotlight  \
# 148516  https://www.kickstarter.com/discover/categorie...      False
# 44169   https://www.kickstarter.com/discover/categorie...      False
# 80052   https://www.kickstarter.com/discover/categorie...      False
# 93623   https://www.kickstarter.com/discover/categorie...      False
# 199356  https://www.kickstarter.com/discover/categorie...      False
#
#         staff_pick   state    state_changed_at  static_usd_rate  \
# 148516       False  failed 2016-11-18 15:32:40          1.00000
# 44169        False  failed 2015-11-26 17:25:33          1.00000
# 80052         True  failed 2015-07-30 20:28:11          0.81191
# 93623        False  failed 2018-10-21 05:51:56          1.00000
# 199356       False  failed 2017-09-21 13:46:44          1.28780
#
#                                                      urls  usd_pledged  \
# 148516  {"web":{"project":"https://www.kickstarter.com...    62.000000
# 44169   {"web":{"project":"https://www.kickstarter.com...   776.000000
# 80052   {"web":{"project":"https://www.kickstarter.com...  2271.723453
# 93623   {"web":{"project":"https://www.kickstarter.com...    96.000000
# 199356  {"web":{"project":"https://www.kickstarter.com...    64.390007
#
#              usd_type    lat    long  average_pledge  usd_goal  \
# 148516  international  39.90 -102.10           15.50  15000.00
# 44169        domestic  39.90 -102.10           43.11  20000.00
# 80052   international  60.26 -110.66           51.38  14614.38
# 93623   international  39.90 -102.10           32.00   2500.00
# 199356       domestic  53.44   -1.64           67.00   1931.70
#
#                           cat    main_cat        sub_cat  profile_id_counts  \
# 148516      music/world music       music    world music                  1
# 44169             food/spaces        food         spaces                  1
# 80052   fashion/ready-to-wear     fashion  ready-to-wear                  1
# 93623             food/drinks        food         drinks                  2
# 199356    technology/software  technology       software                  1
#
#         key_word_count month  year weekday_start weekday_end  duration  \
# 148516               3    10  2016             3           5        30
# 44169                9    10  2015             2           4        30
# 80052                5     6  2015             1           4        45
# 93623                2     8  2018             3           7        60
# 199356               6     8  2017             2           4        30
#
#         blurb_len
# 148516         24
# 44169          24
# 80052          26
# 93623          21
# 199356         19

# %%
dflive = df[df.state == "live"]

# %%
dflive.head()
# Out:
#         backers_count                                              blurb  \
# 144180            226  Conclave: The Papal Election LARP. You play as...
# 141211              9  A modular frame set for collectors of physical...
# 193455            281  A Limited Edition coffee table book of epic Je...
# 177071              3  PowerFlash integrates flash drive & power bank...
# 196585             52  Elvie is a singer/songwriter who just released...
#
#                                                  category  \
# 144180  {"id":34,"name":"Tabletop Games","slug":"games...
# 141211  {"id":28,"name":"Product Design","slug":"desig...
# 193455  {"id":280,"name":"Photobooks","slug":"photogra...
# 177071  {"id":52,"name":"Hardware","slug":"technology/...
# 196585  {"id":40,"name":"Indie Rock","slug":"music/ind...
#
#         converted_pledged_amount country          created_at  \
# 144180                      5637      US 2018-06-26 18:37:11
# 141211                       263      US 2018-11-28 17:54:46
# 193455                     33182      US 2019-02-03 20:49:29
# 177071                        63      US 2018-10-02 10:04:47
# 196585                      6329      US 2019-03-03 02:03:35
#
#                                                   creator currency  \
# 144180  {"id":1763763660,"name":"Willow","is_registere...      USD
# 141211  {"id":1701257242,"name":"Anthony Sansone","slu...      USD
# 193455  {"id":915441459,"name":"Bob Minkin","slug":"ju...      USD
# 177071  {"id":2023737937,"name":"Tek Maker Co","is_reg...      USD
# 196585  {"id":379947972,"name":"Elvie","slug":"elvie",...      USD
#
#        currency_symbol  currency_trailing_code current_currency  \
# 144180               $                    True              USD
# 141211               $                    True              USD
# 193455               $                    True              USD
# 177071               $                    True              USD
# 196585               $                    True              USD
#
#                   deadline  disable_communication  fx_rate     goal  \
# 144180 2019-03-14 12:00:06                  False      1.0   2500.0
# 141211 2019-03-16 23:29:16                  False      1.0   1200.0
# 193455 2019-03-31 18:18:07                  False      1.0  20000.0
# 177071 2019-03-28 15:53:52                  False      1.0  30000.0
# 196585 2019-05-05 03:57:50                  False      1.0   2000.0
#
#         is_starrable         launched_at  \
# 144180         False 2019-02-12 13:00:06
# 141211          True 2019-02-15 00:29:16
# 193455          True 2019-03-01 18:18:07
# 177071          True 2019-02-11 16:53:52
# 196585          True 2019-03-06 03:57:50
#
#                                                  location  \
# 144180  {"id":2443945,"name":"Madison","slug":"madison...
# 141211  {"id":2379574,"name":"Chicago","slug":"chicago...
# 193455  {"id":2462429,"name":"Novato","slug":"novato-c...
# 177071  {"id":2306179,"name":"Taipei City","slug":"tai...
# 196585  {"id":2378317,"name":"Charleston","slug":"char...
#
#                                                      name  \
# 144180                                           Conclave
# 141211               INPUT FRAMES : Magnetic Frame System
# 193455  Just Jerry : Jerry Garcia Photographed by Bob ...
# 177071  PowerFlash - a flash drive & battery with a ty...
# 196585                              Elvie - "So Dramatic"
#
#                                                     photo  pledged  \
# 144180  {"key":"assets/021/705/751/499685c28d9ed0ce3e0...   5637.0
# 141211  {"key":"assets/024/169/503/ad017578f9f37fd642a...    263.0
# 193455  {"key":"assets/024/376/122/bfb5d9d8caaf31be8c5...  33182.0
# 177071  {"key":"assets/023/801/320/129e2a4ccb6ddb43b2b...     63.0
# 196585  {"key":"assets/024/271/228/11a750405daf0f09e1a...   6329.0
#
#                                                   profile  \
# 144180  {"id":3412722,"project_id":3412722,"state":"in...
# 141211  {"id":3524649,"project_id":3524649,"state":"in...
# 193455  {"id":3661738,"project_id":3661738,"state":"in...
# 177071  {"id":3482723,"project_id":3482723,"state":"in...
# 196585  {"id":3680707,"project_id":3680707,"state":"in...
#
#                                                      slug  \
# 144180                                         conclave-0
# 141211                 input-frames-magnetic-frame-system
# 193455  just-jerry-jerry-garcia-photographed-by-bob-mi...
# 177071  powerflash-a-flash-drive-and-battery-with-a-ty...
# 196585                                  elvie-so-dramatic
#
#                                                source_url  spotlight  \
# 144180  https://www.kickstarter.com/discover/categorie...      False
# 141211  https://www.kickstarter.com/discover/categorie...      False
# 193455  https://www.kickstarter.com/discover/categorie...      False
# 177071  https://www.kickstarter.com/discover/categorie...      False
# 196585  https://www.kickstarter.com/discover/categorie...      False
#
#         staff_pick state    state_changed_at  static_usd_rate  \
# 144180        True  live 2019-02-12 13:00:06              1.0
# 141211       False  live 2019-02-15 00:29:16              1.0
# 193455       False  live 2019-03-01 18:18:07              1.0
# 177071       False  live 2019-02-11 16:53:52              1.0
# 196585        True  live 2019-03-06 03:57:51              1.0
#
#                                                      urls  usd_pledged  \
# 144180  {"web":{"project":"https://www.kickstarter.com...       5637.0
# 141211  {"web":{"project":"https://www.kickstarter.com...        263.0
# 193455  {"web":{"project":"https://www.kickstarter.com...      33182.0
# 177071  {"web":{"project":"https://www.kickstarter.com...         63.0
# 196585  {"web":{"project":"https://www.kickstarter.com...       6329.0
#
#              usd_type   lat   long  average_pledge  usd_goal  \
# 144180  international  39.9 -102.1           24.94    2500.0
# 141211  international  39.9 -102.1           29.22    1200.0
# 193455  international  39.9 -102.1          118.09   20000.0
# 177071       domestic  39.9 -102.1           21.00   30000.0
# 196585  international  39.9 -102.1          121.71    2000.0
#
#                            cat     main_cat         sub_cat  \
# 144180    games/tabletop games        games  tabletop games
# 141211   design/product design       design  product design
# 193455  photography/photobooks  photography      photobooks
# 177071     technology/hardware   technology        hardware
# 196585        music/indie rock        music      indie rock
#
#         profile_id_counts  key_word_count month  year weekday_start  \
# 144180                  1               2     2  2019             2
# 141211                  2               5     2  2019             5
# 193455                  3               8     3  2019             5
# 177071                  1              10     2  2019             1
# 196585                  1               3     3  2019             3
#
#        weekday_end  duration  blurb_len
# 144180           4        29         24
# 141211           6        29         18
# 193455           7        30         19
# 177071           4        44         20
# 196585           7        60         23

# %%
df = pd.concat([dfsuc,dffail], axis=0, ignore_index=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 168764 entries, 0 to 168763
# Data columns (total 47 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   backers_count             168764 non-null  int64
#  1   blurb                     168764 non-null  object
#  2   category                  168764 non-null  object
#  3   converted_pledged_amount  168764 non-null  int64
#  4   country                   168764 non-null  object
#  5   created_at                168764 non-null  datetime64[ns]
#  6   creator                   168764 non-null  object
#  7   currency                  168764 non-null  object
#  8   currency_symbol           168764 non-null  object
#  9   currency_trailing_code    168764 non-null  bool
#  10  current_currency          168764 non-null  object
#  11  deadline                  168764 non-null  datetime64[ns]
#  12  disable_communication     168764 non-null  bool
#  13  fx_rate                   168764 non-null  float64
#  14  goal                      168764 non-null  float64
#  15  is_starrable              168764 non-null  bool
#  16  launched_at               168764 non-null  datetime64[ns]
#  17  location                  168764 non-null  object
#  18  name                      168764 non-null  object
#  19  photo                     168764 non-null  object
#  20  pledged                   168764 non-null  float64
#  21  profile                   168764 non-null  object
#  22  slug                      168764 non-null  object
#  23  source_url                168764 non-null  object
#  24  spotlight                 168764 non-null  bool
#  25  staff_pick                168764 non-null  bool
#  26  state                     168764 non-null  object
#  27  state_changed_at          168764 non-null  datetime64[ns]
#  28  static_usd_rate           168764 non-null  float64
#  29  urls                      168764 non-null  object
#  30  usd_pledged               168764 non-null  float64
#  31  usd_type                  168764 non-null  object
#  32  lat                       168764 non-null  float64
#  33  long                      168764 non-null  float64
#  34  average_pledge            168764 non-null  float64
#  35  usd_goal                  168764 non-null  float64
#  36  cat                       168764 non-null  object
#  37  main_cat                  168764 non-null  object
#  38  sub_cat                   168764 non-null  object
#  39  profile_id_counts         168764 non-null  int64
#  40  key_word_count            168764 non-null  int64
#  41  month                     168764 non-null  object
#  42  year                      168764 non-null  object
#  43  weekday_start             168764 non-null  object
#  44  weekday_end               168764 non-null  object
#  45  duration                  168764 non-null  int16
#  46  blurb_len                 168764 non-null  int64
# dtypes: bool(5), datetime64[ns](4), float64(9), int16(1), int64(5), object(23)
# memory usage: 53.9+ MB

# %% [markdown]
# ## countries

# %%
hue_order = ["successful","failed"]
sns.barplot(x="country", y="prob",
            data = df["state"].groupby(df["country"]).value_counts(normalize=True).rename("prob").reset_index(),
            hue="state",edgecolor="grey",linewidth=2.5,hue_order=hue_order)
plt.xticks(rotation=90)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0., fancybox=True);

# %%
sns.countplot(df.country, hue=df.state,edgecolor="grey",linewidth=2.5)
plt.xticks(rotation=90)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0., fancybox=True)
plt.yscale("log")
plt.ylim(100,100000);

# %% [markdown]
# ## categories

# %%
sns.countplot(df.main_cat, hue=df.state,edgecolor="grey",linewidth=2.5)
plt.xticks(rotation=90)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0., fancybox=True);

# %%
fig, ax = plt.subplots(ncols=2, nrows=8,figsize=(20,60),gridspec_kw={'hspace': 0.7})

for idx, elm in enumerate(df.main_cat.unique()):
    #plt.figure(idx, figsize=(6,4))
    sns.countplot(data=df[df["main_cat"] == elm],x="sub_cat", hue=df.state,ax=ax[int(idx/2)][idx%2],edgecolor="grey",linewidth=2.5)
    ax[int(idx/2)][idx%2].tick_params(rotation=90)
    ax[int(idx/2)][idx%2].set_title(elm)
    ax[int(idx/2)][idx%2].set_ylabel("")
    ax[int(idx/2)][idx%2].set_xlabel("")
    ax[int(idx/2)][idx%2].legend().set_visible(False)
handles, labels = ax[1][0].get_legend_handles_labels()
ax[7][1].set_visible(False)
fig.legend(handles, labels,loc=(0.5,0.095));

# %% [markdown]
# ## goal

# %%
sns.boxplot(data=df, x="main_cat", y="usd_goal", hue="state")
plt.xticks(rotation=90)
plt.yscale("symlog")
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0., fancybox=True);

# %%
sns.boxplot(data=df, y="usd_goal",x="staff_pick",hue="state")
plt.xticks(rotation=90)
plt.yscale("symlog")
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0., fancybox=True);

# %% [markdown]
# ## bolean features

# %%
fig, ax = plt.subplots(ncols=2, nrows=2,figsize=(20,20),gridspec_kw={'wspace': 0.5})
sns.countplot(df.spotlight, hue=df.state,edgecolor="grey",ax=ax[0][0],linewidth=2.5)
sns.countplot(df.staff_pick, hue=df.state,edgecolor="grey",ax=ax[0][1],linewidth=2.5)
sns.countplot(df.disable_communication, hue=df.state,edgecolor="grey",ax=ax[1][0],linewidth=2.5)
sns.countplot(df.is_starrable, hue=df.state,edgecolor="grey",ax=ax[1][1],linewidth=2.5)
ax[0][0].legend().set_visible(False)
ax[0][1].legend().set_visible(False)
ax[1][0].legend().set_visible(False)
ax[1][1].legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0., fancybox=True);

# %% [markdown]
# ## keywords

# %%
sns.countplot(df.key_word_count, hue=df.state,edgecolor="grey",linewidth=2.5)
plt.xticks(rotation=90)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0., fancybox=True);

# %% [markdown]
# ## profile id counts

# %%
hue_order = ["successful","failed"]
sns.barplot(x="profile_id_counts", y="prob",
            data = df["state"].groupby(df["profile_id_counts"]).value_counts(normalize=True).rename("prob").reset_index(),
            hue="state",edgecolor="grey",linewidth=2.5,hue_order=hue_order)
plt.xticks(rotation=90)
plt.ylabel("Success rate")
plt.xlabel("No. of projects from the same account")
plt.legend(title=None);
#plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0., fancybox=True);
plt.savefig("profile_id_counts.png", dpi=300,bbox_inches='tight')

# %% [markdown]
# ## year and date

# %%
sns.countplot(data=df, x = 'year', hue = 'state',edgecolor="grey",linewidth=2.5)
plt.title("launch year")
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0., fancybox=True);

# %%
sns.countplot(data=df, x = 'weekday_start', hue = 'state',edgecolor="grey",linewidth=2.5)
plt.title("launch day")
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0., fancybox=True);

# %%
sns.countplot(data=df, x = 'weekday_end', hue = 'state',edgecolor="grey",linewidth=2.5)
plt.title("end day")
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0., fancybox=True);

# %% [markdown]
# ## maps

# %%
df_map = df["state"].groupby(df["country"]).value_counts(normalize=True).rename("Success rate").reset_index()

# %%
df_map2 = df["state"].groupby([df["country"],df["year"]]).value_counts(normalize=True).rename("Success rate").reset_index()

# %%
df_map2 = df_map2[df_map2["year"] !=2019].copy()

# %%
df_map["Success rate"] = round(df_map["Success rate"],2) 
df_map2["Success rate"] = round(df_map2["Success rate"],2)

# %%
df_map["size"]=10
df_map2["size"]=10

# %%
lat={"US":39.9,"GB":53.44,"FR":47.07,"AU":-25,"NZ":-41.93,'ES':40.06, 'IT':43.03, 'NO':61.52, 'NL':52.2, 'CA':60.26, 'SG':1.37,
       'MX':24.25, 'SE':62.89, 'IE':53.36, 'DE':51.08, 'BE':50.68, 'HK':22.39, 'AT':47.69, 'JP':36.59, 'DK':55.95, 'CH':46.89, 'LU':49.64}
long={"US": -102.1,"GB":-1.64,"FR":2.4,"AU":134.12,"NZ":172.88,'ES':-3.5, 'IT':12.6, 'NO':9.49, 'NL':5.65, 'CA':-110.66, 'SG':103.81,
       'MX':-102.45, 'SE':16.88, 'IE':-7.62, 'DE':10.34, 'BE':4.77, 'HK':114.16, 'AT':14.85, 'JP':139.16, 'DK':9.4, 'CH':8.21, 'LU':6.14}

# %%
df_map["lat"]=[lat[elm] for elm in df_map.country.values]
df_map["long"]=[long[elm] for elm in df_map.country.values]

# %%
df_map2["lat"]=[lat[elm] for elm in df_map2.country.values]
df_map2["long"]=[long[elm] for elm in df_map2.country.values]

# %%
fig = px.scatter_mapbox(df_map[df_map["state"]=="successful"], lat="lat", lon="long", 
                        hover_name="country",
                        #text="state",
                        hover_data=["Success rate"],
                        zoom=0.75, 
                        #center={"lat":51.1, "lon":10.3},
                        color_continuous_scale=px.colors.sequential.Jet,
                        height=500, color="Success rate",
                        mapbox_style="open-street-map",opacity=1,
                        size="size", size_max=10,
                        title="Success rate by country")
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.update_layout(
    showlegend=False,
    annotations=[
        dict(
            x=0.13,
            y=0,
            text="Total",
            font=dict(
                color="black",
                size=75
            )
        )
    ]
)

fig.show()
# Out:
# <div>
#
#
#             <div id="439d98b6-274f-4605-a12d-cc72b4dec6a1" class="plotly-graph-div" style="height:500px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("439d98b6-274f-4605-a12d-cc72b4dec6a1")) {
#                     Plotly.newPlot(
#                         '439d98b6-274f-4605-a12d-cc72b4dec6a1',
#                         [{"customdata": [[0.37], [0.47], [0.39], [0.52], [0.41], [0.42], [0.54], [0.41], [0.49], [0.59], [0.7], [0.47], [0.28], [0.62], [0.58], [0.41], [0.39], [0.46], [0.52], [0.5], [0.56], [0.58]], "hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>size=%{marker.size}<br>Success rate=%{marker.color}<br>lat=%{lat}<br>long=%{lon}", "hovertext": ["AT", "AU", "BE", "CA", "CH", "DE", "DK", "ES", "FR", "GB", "HK", "IE", "IT", "JP", "LU", "MX", "NL", "NO", "NZ", "SE", "SG", "US"], "lat": [47.69, -25.0, 50.68, 60.26, 46.89, 51.08, 55.95, 40.06, 47.07, 53.44, 22.39, 53.36, 43.03, 36.59, 49.64, 24.25, 52.2, 61.52, -41.93, 62.89, 1.37, 39.9], "legendgroup": "", "lon": [14.85, 134.12, 4.77, -110.66, 8.21, 10.34, 9.4, -3.5, 2.4, -1.64, 114.16, -7.62, 12.6, 139.16, 6.14, -102.45, 5.65, 9.49, 172.88, 16.88, 103.81, -102.1], "marker": {"color": [0.37, 0.47, 0.39, 0.52, 0.41, 0.42, 0.54, 0.41, 0.49, 0.59, 0.7, 0.47, 0.28, 0.62, 0.58, 0.41, 0.39, 0.46, 0.52, 0.5, 0.56, 0.58], "coloraxis": "coloraxis", "opacity": 1, "size": [10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10], "sizemode": "area", "sizeref": 0.1}, "mode": "markers", "name": "", "showlegend": false, "subplot": "mapbox", "type": "scattermapbox"}],
#                         {"annotations": [{"font": {"color": "black", "size": 75}, "text": "2018", "x": 0.13, "y": 0}], "coloraxis": {"colorbar": {"title": {"text": "Success rate"}}, "colorscale": [[0.0, "rgb(0,0,131)"], [0.2, "rgb(0,60,170)"], [0.4, "rgb(5,255,255)"], [0.6, "rgb(255,255,0)"], [0.8, "rgb(250,0,0)"], [1.0, "rgb(128,0,0)"]]}, "height": 500, "legend": {"itemsizing": "constant", "tracegroupgap": 0}, "mapbox": {"center": {"lat": 37.87863636363637, "lon": 19.858636363636364}, "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "style": "open-street-map", "zoom": 0.75}, "margin": {"b": 0, "l": 0, "r": 0, "t": 0}, "showlegend": false, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colo ...

# %%
df_map2 = df_map2.sort_values("year").copy()

# %%
df_map2_suc = df_map2[df_map2["state"]=="successful"]

# %%
np.arange(2009,2019)
# Out:
# array([2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018])

# %%
for year in np.arange(2009,2019):

    fig = px.scatter_mapbox(df_map2_suc[df_map2_suc["year"]==year], lat="lat", lon="long", 
                            hover_name="country",
                            #text="state",
                            hover_data=["Success rate"],
                            zoom=0.75, 
                            center={"lat":47.51, "lon":10.74},
                            color_continuous_scale=px.colors.sequential.Jet,
                            height=700, color="Success rate",
                            mapbox_style="open-street-map",opacity=1,
                            size="size", size_max=10,
                            title="Success rate by country",
                            #animation_frame="year",
                            range_color=[df_map2["Success rate"].min(),df_map2["Success rate"].max()])
    fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
    fig.update_layout(
    showlegend=False,
    annotations=[
        dict(
            x=0.13,
            y=0,
            text=str(year),
            font=dict(
                color="black",
                size=75
            )
        )
    ]
    )
    fig.show()
    fig.write_image("map"+str(year)+".png", width=1000, height=700, scale =3)
# Out:
# <div>
#
#
#             <div id="565e28c1-0b7c-4ae2-a1ce-3d1c04b20312" class="plotly-graph-div" style="height:700px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("565e28c1-0b7c-4ae2-a1ce-3d1c04b20312")) {
#                     Plotly.newPlot(
#                         '565e28c1-0b7c-4ae2-a1ce-3d1c04b20312',
#                         [{"customdata": [[0.84]], "hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>size=%{marker.size}<br>Success rate=%{marker.color}<br>lat=%{lat}<br>long=%{lon}", "hovertext": ["US"], "lat": [39.9], "legendgroup": "", "lon": [-102.1], "marker": {"color": [0.84], "coloraxis": "coloraxis", "opacity": 1, "size": [10], "sizemode": "area", "sizeref": 0.1}, "mode": "markers", "name": "", "showlegend": false, "subplot": "mapbox", "type": "scattermapbox"}],
#                         {"annotations": [{"font": {"color": "black", "size": 75}, "text": "2009", "x": 0.13, "y": 0}], "coloraxis": {"cmax": 0.86, "cmin": 0.14, "colorbar": {"title": {"text": "Success rate"}}, "colorscale": [[0.0, "rgb(0,0,131)"], [0.2, "rgb(0,60,170)"], [0.4, "rgb(5,255,255)"], [0.6, "rgb(255,255,0)"], [0.8, "rgb(250,0,0)"], [1.0, "rgb(128,0,0)"]]}, "height": 700, "legend": {"itemsizing": "constant", "tracegroupgap": 0}, "mapbox": {"center": {"lat": 47.51, "lon": 10.74}, "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "style": "open-street-map", "zoom": 0.75}, "margin": {"b": 0, "l": 0, "r": 0, "t": 0}, "showlegend": false, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"c ...
# <div>
#
#
#             <div id="3929d9d9-316c-4748-8a49-b91ec182155e" class="plotly-graph-div" style="height:700px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("3929d9d9-316c-4748-8a49-b91ec182155e")) {
#                     Plotly.newPlot(
#                         '3929d9d9-316c-4748-8a49-b91ec182155e',
#                         [{"customdata": [[0.78]], "hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>size=%{marker.size}<br>Success rate=%{marker.color}<br>lat=%{lat}<br>long=%{lon}", "hovertext": ["US"], "lat": [39.9], "legendgroup": "", "lon": [-102.1], "marker": {"color": [0.78], "coloraxis": "coloraxis", "opacity": 1, "size": [10], "sizemode": "area", "sizeref": 0.1}, "mode": "markers", "name": "", "showlegend": false, "subplot": "mapbox", "type": "scattermapbox"}],
#                         {"annotations": [{"font": {"color": "black", "size": 75}, "text": "2010", "x": 0.13, "y": 0}], "coloraxis": {"cmax": 0.86, "cmin": 0.14, "colorbar": {"title": {"text": "Success rate"}}, "colorscale": [[0.0, "rgb(0,0,131)"], [0.2, "rgb(0,60,170)"], [0.4, "rgb(5,255,255)"], [0.6, "rgb(255,255,0)"], [0.8, "rgb(250,0,0)"], [1.0, "rgb(128,0,0)"]]}, "height": 700, "legend": {"itemsizing": "constant", "tracegroupgap": 0}, "mapbox": {"center": {"lat": 47.51, "lon": 10.74}, "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "style": "open-street-map", "zoom": 0.75}, "margin": {"b": 0, "l": 0, "r": 0, "t": 0}, "showlegend": false, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"c ...
# <div>
#
#
#             <div id="ae49775c-3553-4d05-87c0-ff995140ca92" class="plotly-graph-div" style="height:700px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ae49775c-3553-4d05-87c0-ff995140ca92")) {
#                     Plotly.newPlot(
#                         'ae49775c-3553-4d05-87c0-ff995140ca92',
#                         [{"customdata": [[0.79]], "hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>size=%{marker.size}<br>Success rate=%{marker.color}<br>lat=%{lat}<br>long=%{lon}", "hovertext": ["US"], "lat": [39.9], "legendgroup": "", "lon": [-102.1], "marker": {"color": [0.79], "coloraxis": "coloraxis", "opacity": 1, "size": [10], "sizemode": "area", "sizeref": 0.1}, "mode": "markers", "name": "", "showlegend": false, "subplot": "mapbox", "type": "scattermapbox"}],
#                         {"annotations": [{"font": {"color": "black", "size": 75}, "text": "2011", "x": 0.13, "y": 0}], "coloraxis": {"cmax": 0.86, "cmin": 0.14, "colorbar": {"title": {"text": "Success rate"}}, "colorscale": [[0.0, "rgb(0,0,131)"], [0.2, "rgb(0,60,170)"], [0.4, "rgb(5,255,255)"], [0.6, "rgb(255,255,0)"], [0.8, "rgb(250,0,0)"], [1.0, "rgb(128,0,0)"]]}, "height": 700, "legend": {"itemsizing": "constant", "tracegroupgap": 0}, "mapbox": {"center": {"lat": 47.51, "lon": 10.74}, "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "style": "open-street-map", "zoom": 0.75}, "margin": {"b": 0, "l": 0, "r": 0, "t": 0}, "showlegend": false, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"c ...
# <div>
#
#
#             <div id="0a5aea66-e92a-46d8-9e32-b2279a11e36d" class="plotly-graph-div" style="height:700px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("0a5aea66-e92a-46d8-9e32-b2279a11e36d")) {
#                     Plotly.newPlot(
#                         '0a5aea66-e92a-46d8-9e32-b2279a11e36d',
#                         [{"customdata": [[0.62], [0.78]], "hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>size=%{marker.size}<br>Success rate=%{marker.color}<br>lat=%{lat}<br>long=%{lon}", "hovertext": ["GB", "US"], "lat": [53.44, 39.9], "legendgroup": "", "lon": [-1.64, -102.1], "marker": {"color": [0.62, 0.78], "coloraxis": "coloraxis", "opacity": 1, "size": [10, 10], "sizemode": "area", "sizeref": 0.1}, "mode": "markers", "name": "", "showlegend": false, "subplot": "mapbox", "type": "scattermapbox"}],
#                         {"annotations": [{"font": {"color": "black", "size": 75}, "text": "2012", "x": 0.13, "y": 0}], "coloraxis": {"cmax": 0.86, "cmin": 0.14, "colorbar": {"title": {"text": "Success rate"}}, "colorscale": [[0.0, "rgb(0,0,131)"], [0.2, "rgb(0,60,170)"], [0.4, "rgb(5,255,255)"], [0.6, "rgb(255,255,0)"], [0.8, "rgb(250,0,0)"], [1.0, "rgb(128,0,0)"]]}, "height": 700, "legend": {"itemsizing": "constant", "tracegroupgap": 0}, "mapbox": {"center": {"lat": 47.51, "lon": 10.74}, "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "style": "open-street-map", "zoom": 0.75}, "margin": {"b": 0, "l": 0, "r": 0, "t": 0}, "showlegend": false, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"c ...
# <div>
#
#
#             <div id="a62511b0-b252-47b6-b627-94d953967d88" class="plotly-graph-div" style="height:700px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a62511b0-b252-47b6-b627-94d953967d88")) {
#                     Plotly.newPlot(
#                         'a62511b0-b252-47b6-b627-94d953967d88',
#                         [{"customdata": [[0.75], [0.7], [0.76], [0.81], [0.73]], "hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>size=%{marker.size}<br>Success rate=%{marker.color}<br>lat=%{lat}<br>long=%{lon}", "hovertext": ["NZ", "GB", "AU", "US", "CA"], "lat": [-41.93, 53.44, -25.0, 39.9, 60.26], "legendgroup": "", "lon": [172.88, -1.64, 134.12, -102.1, -110.66], "marker": {"color": [0.75, 0.7, 0.76, 0.81, 0.73], "coloraxis": "coloraxis", "opacity": 1, "size": [10, 10, 10, 10, 10], "sizemode": "area", "sizeref": 0.1}, "mode": "markers", "name": "", "showlegend": false, "subplot": "mapbox", "type": "scattermapbox"}],
#                         {"annotations": [{"font": {"color": "black", "size": 75}, "text": "2013", "x": 0.13, "y": 0}], "coloraxis": {"cmax": 0.86, "cmin": 0.14, "colorbar": {"title": {"text": "Success rate"}}, "colorscale": [[0.0, "rgb(0,0,131)"], [0.2, "rgb(0,60,170)"], [0.4, "rgb(5,255,255)"], [0.6, "rgb(255,255,0)"], [0.8, "rgb(250,0,0)"], [1.0, "rgb(128,0,0)"]]}, "height": 700, "legend": {"itemsizing": "constant", "tracegroupgap": 0}, "mapbox": {"center": {"lat": 47.51, "lon": 10.74}, "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "style": "open-street-map", "zoom": 0.75}, "margin": {"b": 0, "l": 0, "r": 0, "t": 0}, "showlegend": false, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"c ...
# <div>
#
#
#             <div id="fbe5646b-0d3f-46be-8aa5-b728b38ed671" class="plotly-graph-div" style="height:700px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("fbe5646b-0d3f-46be-8aa5-b728b38ed671")) {
#                     Plotly.newPlot(
#                         'fbe5646b-0d3f-46be-8aa5-b728b38ed671',
#                         [{"customdata": [[0.55], [0.28], [0.47], [0.53], [0.46], [0.45], [0.48], [0.55], [0.39], [0.33]], "hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>size=%{marker.size}<br>Success rate=%{marker.color}<br>lat=%{lat}<br>long=%{lon}", "hovertext": ["NO", "NL", "IE", "GB", "DK", "CA", "NZ", "US", "AU", "SE"], "lat": [61.52, 52.2, 53.36, 53.44, 55.95, 60.26, -41.93, 39.9, -25.0, 62.89], "legendgroup": "", "lon": [9.49, 5.65, -7.62, -1.64, 9.4, -110.66, 172.88, -102.1, 134.12, 16.88], "marker": {"color": [0.55, 0.28, 0.47, 0.53, 0.46, 0.45, 0.48, 0.55, 0.39, 0.33], "coloraxis": "coloraxis", "opacity": 1, "size": [10, 10, 10, 10, 10, 10, 10, 10, 10, 10], "sizemode": "area", "sizeref": 0.1}, "mode": "markers", "name": "", "showlegend": false, "subplot": "mapbox", "type": "scattermapbox"}],
#                         {"annotations": [{"font": {"color": "black", "size": 75}, "text": "2014", "x": 0.13, "y": 0}], "coloraxis": {"cmax": 0.86, "cmin": 0.14, "colorbar": {"title": {"text": "Success rate"}}, "colorscale": [[0.0, "rgb(0,0,131)"], [0.2, "rgb(0,60,170)"], [0.4, "rgb(5,255,255)"], [0.6, "rgb(255,255,0)"], [0.8, "rgb(250,0,0)"], [1.0, "rgb(128,0,0)"]]}, "height": 700, "legend": {"itemsizing": "constant", "tracegroupgap": 0}, "mapbox": {"center": {"lat": 47.51, "lon": 10.74}, "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "style": "open-street-map", "zoom": 0.75}, "margin": {"b": 0, "l": 0, "r": 0, "t": 0}, "showlegend": false, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"c ...
# <div>
#
#
#             <div id="4a1e008f-9350-4f7d-b1eb-10cc111e6826" class="plotly-graph-div" style="height:700px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4a1e008f-9350-4f7d-b1eb-10cc111e6826")) {
#                     Plotly.newPlot(
#                         '4a1e008f-9350-4f7d-b1eb-10cc111e6826',
#                         [{"customdata": [[0.36], [0.44], [0.4], [0.51], [0.37], [0.14], [0.5], [0.42], [0.31], [0.31], [0.25], [0.22], [0.25], [0.44], [0.38], [0.26], [0.41], [0.3]], "hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>size=%{marker.size}<br>Success rate=%{marker.color}<br>lat=%{lat}<br>long=%{lon}", "hovertext": ["FR", "US", "SE", "GB", "IE", "IT", "LU", "NZ", "NL", "NO", "ES", "BE", "CH", "DK", "AU", "AT", "CA", "DE"], "lat": [47.07, 39.9, 62.89, 53.44, 53.36, 43.03, 49.64, -41.93, 52.2, 61.52, 40.06, 50.68, 46.89, 55.95, -25.0, 47.69, 60.26, 51.08], "legendgroup": "", "lon": [2.4, -102.1, 16.88, -1.64, -7.62, 12.6, 6.14, 172.88, 5.65, 9.49, -3.5, 4.77, 8.21, 9.4, 134.12, 14.85, -110.66, 10.34], "marker": {"color": [0.36, 0.44, 0.4, 0.51, 0.37, 0.14, 0.5, 0.42, 0.31, 0.31, 0.25, 0.22, 0.25, 0.44, 0.38, 0.26, 0.41, 0.3], "coloraxis": "coloraxis", "opacity": 1, "size": [10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10], "sizemode": "area", "sizeref": 0.1}, "mode": "markers", "name": "", "showlegend": false, "subplot": "mapbox", "type": "scattermapbox"}],
#                         {"annotations": [{"font": {"color": "black", "size": 75}, "text": "2015", "x": 0.13, "y": 0}], "coloraxis": {"cmax": 0.86, "cmin": 0.14, "colorbar": {"title": {"text": "Success rate"}}, "colorscale": [[0.0, "rgb(0,0,131)"], [0.2, "rgb(0,60,170)"], [0.4, "rgb(5,255,255)"], [0.6, "rgb(255,255,0)"], [0.8, "rgb(250,0,0)"], [1.0, "rgb(128,0,0)"]]}, "height": 700, "legend": {"itemsizing": "constant", "tracegroupgap": 0}, "mapbox": {"center": {"lat": 47.51, "lon": 10.74}, "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "style": "open-street-map", "zoom": 0.75}, "margin": {"b": 0, "l": 0, "r": 0, "t": 0}, "showlegend": false, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"c ...
# <div>
#
#
#             <div id="a9fe6437-e954-4740-988f-68efbf7a4580" class="plotly-graph-div" style="height:700px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a9fe6437-e954-4740-988f-68efbf7a4580")) {
#                     Plotly.newPlot(
#                         'a9fe6437-e954-4740-988f-68efbf7a4580',
#                         [{"customdata": [[0.4], [0.52], [0.5], [0.62], [0.5], [0.38], [0.33], [0.25], [0.45], [0.47], [0.37], [0.51], [0.33], [0.48], [0.48], [0.44], [0.43], [0.47], [0.38], [0.58], [0.3]], "hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>size=%{marker.size}<br>Success rate=%{marker.color}<br>lat=%{lat}<br>long=%{lon}", "hovertext": ["HK", "SE", "IE", "LU", "NZ", "BE", "CH", "IT", "SG", "FR", "NL", "DK", "ES", "US", "CA", "NO", "MX", "AU", "DE", "GB", "AT"], "lat": [22.39, 62.89, 53.36, 49.64, -41.93, 50.68, 46.89, 43.03, 1.37, 47.07, 52.2, 55.95, 40.06, 39.9, 60.26, 61.52, 24.25, -25.0, 51.08, 53.44, 47.69], "legendgroup": "", "lon": [114.16, 16.88, -7.62, 6.14, 172.88, 4.77, 8.21, 12.6, 103.81, 2.4, 5.65, 9.4, -3.5, -102.1, -110.66, 9.49, -102.45, 134.12, 10.34, -1.64, 14.85], "marker": {"color": [0.4, 0.52, 0.5, 0.62, 0.5, 0.38, 0.33, 0.25, 0.45, 0.47, 0.37, 0.51, 0.33, 0.48, 0.48, 0.44, 0.43, 0.47, 0.38, 0.58, 0.3], "coloraxis": "coloraxis", "opacity": 1, "size": [10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10], "sizemode": "area", "sizeref": 0.1}, "mode": "markers", "name": "", "showlegend": false, "subplot": "mapbox", "type": "scattermapbox"}],
#                         {"annotations": [{"font": {"color": "black", "size": 75}, "text": "2016", "x": 0.13, "y": 0}], "coloraxis": {"cmax": 0.86, "cmin": 0.14, "colorbar": {"title": {"text": "Success rate"}}, "colorscale": [[0.0, "rgb(0,0,131)"], [0.2, "rgb(0,60,170)"], [0.4, "rgb(5,255,255)"], [0.6, "rgb(255,255,0)"], [0.8, "rgb(250,0,0)"], [1.0, "rgb(128,0,0)"]]}, "height": 700, "legend": {"itemsizing": "constant", "tracegroupgap": 0}, "mapbox": {"center": {"lat": 47.51, "lon": 10.74}, "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "style": "open-street-map", "zoom": 0.75}, "margin": {"b": 0, "l": 0, "r": 0, "t": 0}, "showlegend": false, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"c ...
# <div>
#
#
#             <div id="0cd57fe2-4f22-4501-9a08-d0a47be1caba" class="plotly-graph-div" style="height:700px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("0cd57fe2-4f22-4501-9a08-d0a47be1caba")) {
#                     Plotly.newPlot(
#                         '0cd57fe2-4f22-4501-9a08-d0a47be1caba',
#                         [{"customdata": [[0.42], [0.55], [0.51], [0.26], [0.48], [0.59], [0.48], [0.47], [0.52], [0.36], [0.36], [0.23], [0.6], [0.42], [0.55], [0.38], [0.46], [0.55], [0.39], [0.6], [0.38], [0.59]], "hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>size=%{marker.size}<br>Success rate=%{marker.color}<br>lat=%{lat}<br>long=%{lon}", "hovertext": ["NL", "CA", "US", "AT", "AU", "NO", "SG", "SE", "NZ", "BE", "DE", "IT", "GB", "CH", "JP", "IE", "FR", "LU", "ES", "DK", "MX", "HK"], "lat": [52.2, 60.26, 39.9, 47.69, -25.0, 61.52, 1.37, 62.89, -41.93, 50.68, 51.08, 43.03, 53.44, 46.89, 36.59, 53.36, 47.07, 49.64, 40.06, 55.95, 24.25, 22.39], "legendgroup": "", "lon": [5.65, -110.66, -102.1, 14.85, 134.12, 9.49, 103.81, 16.88, 172.88, 4.77, 10.34, 12.6, -1.64, 8.21, 139.16, -7.62, 2.4, 6.14, -3.5, 9.4, -102.45, 114.16], "marker": {"color": [0.42, 0.55, 0.51, 0.26, 0.48, 0.59, 0.48, 0.47, 0.52, 0.36, 0.36, 0.23, 0.6, 0.42, 0.55, 0.38, 0.46, 0.55, 0.39, 0.6, 0.38, 0.59], "coloraxis": "coloraxis", "opacity": 1, "size": [10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10], "sizemode": "area", "sizeref": 0.1}, "mode": "markers", "name": "", "showlegend": false, "subplot": "mapbox", "type": "scattermapbox"}],
#                         {"annotations": [{"font": {"color": "black", "size": 75}, "text": "2017", "x": 0.13, "y": 0}], "coloraxis": {"cmax": 0.86, "cmin": 0.14, "colorbar": {"title": {"text": "Success rate"}}, "colorscale": [[0.0, "rgb(0,0,131)"], [0.2, "rgb(0,60,170)"], [0.4, "rgb(5,255,255)"], [0.6, "rgb(255,255,0)"], [0.8, "rgb(250,0,0)"], [1.0, "rgb(128,0,0)"]]}, "height": 700, "legend": {"itemsizing": "constant", "tracegroupgap": 0}, "mapbox": {"center": {"lat": 47.51, "lon": 10.74}, "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "style": "open-street-map", "zoom": 0.75}, "margin": {"b": 0, "l": 0, "r": 0, "t": 0}, "showlegend": false, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"c ...
# <div>
#
#
#             <div id="3896821b-7da8-422b-8c56-b78cea7c9f7e" class="plotly-graph-div" style="height:700px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("3896821b-7da8-422b-8c56-b78cea7c9f7e")) {
#                     Plotly.newPlot(
#                         '3896821b-7da8-422b-8c56-b78cea7c9f7e',
#                         [{"customdata": [[0.62], [0.63], [0.71], [0.66], [0.6], [0.61], [0.54], [0.63], [0.56], [0.78], [0.44], [0.56], [0.6], [0.64], [0.4], [0.56], [0.52], [0.59], [0.64], [0.56], [0.66], [0.63]], "hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>size=%{marker.size}<br>Success rate=%{marker.color}<br>lat=%{lat}<br>long=%{lon}", "hovertext": ["SG", "AU", "GB", "CA", "AT", "FR", "ES", "DK", "DE", "HK", "MX", "NL", "LU", "JP", "IT", "NO", "BE", "IE", "NZ", "CH", "US", "SE"], "lat": [1.37, -25.0, 53.44, 60.26, 47.69, 47.07, 40.06, 55.95, 51.08, 22.39, 24.25, 52.2, 49.64, 36.59, 43.03, 61.52, 50.68, 53.36, -41.93, 46.89, 39.9, 62.89], "legendgroup": "", "lon": [103.81, 134.12, -1.64, -110.66, 14.85, 2.4, -3.5, 9.4, 10.34, 114.16, -102.45, 5.65, 6.14, 139.16, 12.6, 9.49, 4.77, -7.62, 172.88, 8.21, -102.1, 16.88], "marker": {"color": [0.62, 0.63, 0.71, 0.66, 0.6, 0.61, 0.54, 0.63, 0.56, 0.78, 0.44, 0.56, 0.6, 0.64, 0.4, 0.56, 0.52, 0.59, 0.64, 0.56, 0.66, 0.63], "coloraxis": "coloraxis", "opacity": 1, "size": [10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10], "sizemode": "area", "sizeref": 0.1}, "mode": "markers", "name": "", "showlegend": false, "subplot": "mapbox", "type": "scattermapbox"}],
#                         {"annotations": [{"font": {"color": "black", "size": 75}, "text": "2018", "x": 0.13, "y": 0}], "coloraxis": {"cmax": 0.86, "cmin": 0.14, "colorbar": {"title": {"text": "Success rate"}}, "colorscale": [[0.0, "rgb(0,0,131)"], [0.2, "rgb(0,60,170)"], [0.4, "rgb(5,255,255)"], [0.6, "rgb(255,255,0)"], [0.8, "rgb(250,0,0)"], [1.0, "rgb(128,0,0)"]]}, "height": 700, "legend": {"itemsizing": "constant", "tracegroupgap": 0}, "mapbox": {"center": {"lat": 47.51, "lon": 10.74}, "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "style": "open-street-map", "zoom": 0.75}, "margin": {"b": 0, "l": 0, "r": 0, "t": 0}, "showlegend": false, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"c ...

# %% [markdown]
# ## final drop

# %%
df_model=df.drop(["backers_count","converted_pledged_amount","disable_communication",
                 "is_starrable","average_pledge","staff_pick","spotlight","year",
                 'state_changed_at','created_at','launched_at','deadline','main_cat',
                 'sub_cat','goal', 'static_usd_rate', 'fx_rate', 'slug', 'creator', 'category','lat','long',"blurb",
                 "currency","currency_symbol", "currency_trailing_code", "current_currency",
                  "location","name","photo","source_url","urls","usd_type","profile","pledged","usd_pledged"], axis=1)

# %%
df_model.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 168764 entries, 0 to 168763
# Data columns (total 11 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   country            168764 non-null  object
#  1   state              168764 non-null  object
#  2   usd_goal           168764 non-null  float64
#  3   cat                168764 non-null  object
#  4   profile_id_counts  168764 non-null  int64
#  5   key_word_count     168764 non-null  int64
#  6   month              168764 non-null  object
#  7   weekday_start      168764 non-null  object
#  8   weekday_end        168764 non-null  object
#  9   duration           168764 non-null  int16
#  10  blurb_len          168764 non-null  int64
# dtypes: float64(1), int16(1), int64(3), object(6)
# memory usage: 13.2+ MB

# %%
len(df_model.cat.unique())
# Out:
# 169

# %% [markdown]
# ## outlier removal

# %%
df_model.shape
# Out:
# (168764, 11)

# %%
feat=list(df_model.select_dtypes(include=[np.number]).columns.values)

# %%
df1 = df_model[feat]

# %%
df2 = df_model.drop(feat, axis=1)

# %%
from scipy import stats
z = np.abs(stats.zscore(df1))

# %%
df1 = df1[(z < 3).all(axis=1)]

# %%
df_model = pd.concat([df1,df2],axis=1).dropna()

# %%
df_model.shape
# Out:
# (164846, 11)

# %% [markdown]
# ## correlation matrix

# %%
plt.figure (figsize=(12,12))
mask = np.triu(df_model.corr())
ax = sns.heatmap(round(df_model.corr()*100)
                 ,annot=True
                 ,mask=mask
                 ,cmap='coolwarm'
                 ,center=0)
ax.set_ylim((0,10))
ax.set_xlim((0,10));

# %% [markdown]
# ## pair plots

# %%
sns.pairplot(df_model);

# %% [markdown]
# # Visualizations

# %% [markdown]
# ## Total Amount by Year

# %%
dfsuc_year = dfsuc.groupby('year').sum().reset_index()
dfsuc_year.converted_pledged_amount = dfsuc_year.converted_pledged_amount / 1000000
dfsuc_year = dfsuc_year[dfsuc_year.year != 2019]

# %%
sns.barplot(x="year", y="converted_pledged_amount", data=dfsuc_year);
plt.ylabel('pledged in mil. $')
plt.xlabel('');

# %% [markdown]
# # Example Case

# %% [markdown]
# ## lord of the chains

# %%
ex_case = {'country':['DE', 'US'], 'usd_goal':[50000,50000], 'cat':["comics/graphic novels","comics/comic books"],
           'profile_id_counts':[1,20], 'key_word_count':[4,4], "month":['12','10'],'weekday_start':["7","2"],
           'weekday_end':["7","2"],"duration":[35,35],"blurb_len":[20,20]} 
df_excase = pd.Dataframe(ex_case)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-70-c6b5c5c5d8f3> in <module>
#       2            'profile_id_counts':[1,20], 'key_word_count':[4,4], "month":['12','10'],'weekday_start':["7","2"],
#       3            'weekday_end':["7","2"],"duration":[35,35],"blurb_len":[20,20]}
# ----> 4 df_excase = pd.Dataframe(ex_case)
#
# ~\anaconda3\lib\site-packages\pandas\__init__.py in __getattr__(name)
#     260             return _SparseArray
#     261
# --> 262         raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     263
#     264
#
# AttributeError: module 'pandas' has no attribute 'Dataframe'

# %%
df_excase.info()

# %% [markdown]
# # future work

# %% [markdown]
# * Total pledge amount prediction for successful proposals, to maximize our profit
# * In depth analysis of projects’ short description (blurb) to optimize chances of success
# * Prediction of whether or not a project will be chosen as a staff pick
